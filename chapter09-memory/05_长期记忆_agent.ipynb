# %% [markdown]
# # 长期记忆-agent
#
# ## 1、在工具中访问长期记忆
#
# ### 1.1 基于InMemoryStore

# %%
from typing import NotRequired

from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from langchain_core.tools import tool

# 从.env文件中加载环境变量
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    profile={"max_input_tokens":128_000},
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    extra_body={"thinking": {"type": "disabled"}}
)

# %%
from langgraph.prebuilt import ToolRuntime
from langchain_core.messages import HumanMessage
from langgraph.store.memory import InMemoryStore
from langchain.agents import create_agent, AgentState

store = InMemoryStore()

# 自定义一个继承于AgentState的类
class CustomState(AgentState):
    user_id : NotRequired[str]

# 保存用户信息到长期记忆中
@tool(parse_docstring=True)
def save_user_info(name : str , runtime : ToolRuntime) -> str:
    """
    将客户信息保存在长期记忆中

    Args:
        name : 用户名
        runtime : 工具的运行时

    Returns:
        str : 保存状态
    """
    namespace = ("users",)
    key = runtime.state["user_id"]
    value = {"name" : name}

    runtime.store.put(namespace, key, value)
    return "saved"


@tool(parse_docstring=True)
def get_user_info(runtime : ToolRuntime) -> str:
    """
    从长期记忆中读取客户的信息

    Args:
        runtime : 工具的运行时

    Returns:
        str : 用户信息
    """
    namespace = ("users",)
    key = runtime.state["user_id"]

    item = runtime.store.get(namespace,key)
    return str(item.value) if item else "unknown"

agent = create_agent(
    model=model,
    tools=[save_user_info,get_user_info],
    store=store,
    state_schema=CustomState,
    system_prompt="用户提及个人信息时，可以使用工具保存用户信息。如果用户询问个人信息时，可以尝试使用工具读取用户信息"
)

print("=" * 30, '-> 第一个会话（线程） <-', "=" * 30)
response1 = agent.invoke({
    "messages": [HumanMessage("你好，很高兴认识你，我是小花")],
    "user_id": "user-1"
})
for msg in response1["messages"]:
    msg.pretty_print()

print("=" * 30, '-> 第二个会话（线程） <-', "=" * 30)
response2 = agent.invoke({
    "messages": [HumanMessage("我是谁")],
    "user_id": "user-1"
})
for msg in response2["messages"]:
    msg.pretty_print()
# Out:
# ============================== -> 第一个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 你好，很高兴认识你，我是小花
# ================================== Ai Message ==================================
#
# 你好，小花！很高兴认识你！我是你的AI助手，有什么可以帮你的吗？
#
# 让我把你的信息保存下来，这样以后就能记住你了。
# Tool Calls:
#   save_user_info (call_00_F2GyX8PMLyc4huUmDIOd7812)
#  Call ID: call_00_F2GyX8PMLyc4huUmDIOd7812
#   Args:
#     name: 小花
# ================================= Tool Message =================================
# Name: save_user_info
#
# saved
# ================================== Ai Message ==================================
#
# 我已经记住了你的名字，小花！😊 以后有什么需要帮忙的随时告诉我哦～
# ============================== -> 第二个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 我是谁
# ================================== Ai Message ==================================
#
# 让我查看一下您的信息。
# Tool Calls:
#   get_user_info (call_00_2StfHbZuyMaDWE8w2KlP6342)
#  Call ID: call_00_2StfHbZuyMaDWE8w2KlP6342
#   Args:
# ================================= Tool Message =================================
# Name: get_user_info
#
# {'name': '小花'}
# ================================== Ai Message ==================================
#
# 您是小花呀！您好，很高兴为您服务。请问有什么可以帮您的吗？

# %% [markdown]
# ### 1.2 基于PostgresStore

# %%
from langgraph.store.postgres import PostgresStore
from langgraph.prebuilt import ToolRuntime
from langchain_core.messages import HumanMessage
from langgraph.store.memory import InMemoryStore
from langchain.agents import create_agent, AgentState



# 自定义一个继承于AgentState的类
class CustomState(AgentState):
    user_id : NotRequired[str]

# 保存用户信息到长期记忆中
@tool(parse_docstring=True)
def save_user_info(name : str , runtime : ToolRuntime) -> str:
    """
    将客户信息保存在长期记忆中

    Args:
        name : 用户名
        runtime : 工具的运行时

    Returns:
        str : 保存状态
    """
    namespace = ("users",)
    key = runtime.state["user_id"]
    value = {"name" : name}

    runtime.store.put(namespace, key, value)
    return "saved"


@tool(parse_docstring=True)
def get_user_info(runtime : ToolRuntime) -> str:
    """
    从长期记忆中读取客户的信息

    Args:
        runtime : 工具的运行时

    Returns:
        str : 用户信息
    """
    namespace = ("users",)
    key = runtime.state["user_id"]

    item = runtime.store.get(namespace,key)
    return str(item.value) if item else "unknown"

DB_URL = "postgresql://chenweiran:Chenweiran233@pgm-uf65g19via6jrmh78o.pg.rds.aliyuncs.com:5432/myDB?sslmode=prefer"

with PostgresStore.from_conn_string(DB_URL) as store:
    store.setup()

    agent = create_agent(
        model=model,
        tools=[save_user_info,get_user_info],
        store=store,
        state_schema=CustomState,
        system_prompt="用户提及个人信息时，可以使用工具保存用户信息。如果用户询问个人信息时，可以尝试使用工具读取用户信息"
    )

    print("=" * 30, '-> 第一个会话（线程） <-', "=" * 30)
    response1 = agent.invoke({
        "messages": [HumanMessage("你好，很高兴认识你，我是小花")],
        "user_id": "user-1"
    })
    for msg in response1["messages"]:
        msg.pretty_print()

    print("=" * 30, '-> 第二个会话（线程） <-', "=" * 30)
    response2 = agent.invoke({
        "messages": [HumanMessage("我是谁")],
        "user_id": "user-1"
    })
    for msg in response2["messages"]:
        msg.pretty_print()
# Out:
# ============================== -> 第一个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 你好，很高兴认识你，我是小花
# ================================== Ai Message ==================================
#
# 很高兴认识你，小花！😊 让我把你的名字记下来，这样以后我们聊天时我就能记得你了。
# Tool Calls:
#   save_user_info (call_00_opCY5sAPipsf34JTlHQH7805)
#  Call ID: call_00_opCY5sAPipsf34JTlHQH7805
#   Args:
#     name: 小花
# ================================= Tool Message =================================
# Name: save_user_info
#
# saved
# ================================== Ai Message ==================================
#
# 已经记住你的名字啦！小花这个名字真好听～
#
# 请问今天有什么我可以帮助你的吗？无论是聊天、解答问题，还是其他需要，我都会尽力帮你的！😊
# ============================== -> 第二个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 我是谁
# ================================== Ai Message ==================================
#
# 让我帮您查看一下已保存的用户信息。
# Tool Calls:
#   get_user_info (call_00_JE9t2eBvsgyFrblcn0zO1032)
#  Call ID: call_00_JE9t2eBvsgyFrblcn0zO1032
#   Args:
# ================================= Tool Message =================================
# Name: get_user_info
#
# {'name': '小花'}
# ================================== Ai Message ==================================
#
# 根据系统记录，您是**小花**。请问有什么我可以帮助您的吗？😊
