# %% [raw]
# 使用本地ollama的类进行调用

# %%
from langchain_classic.chat_models import init_chat_model
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="deepseek-r1:8b",
    base_url='http://localhost:11434',
)

print(model.invoke("介绍下你自己"))
# Out:
# content='\n你好呀！我是 DeepSeek-R1 🤖\n\n由深度求索（DeepSeek）公司开发的一款智能 AI 助手。我的主要本领是文字处理：你可以把我当作一个会读、写、分析的“超级聊天机器人”来用，能读懂你输入的文字内容，并根据上下文理解你的问题进行回答。\n\n我支持中文和英文交流，对各种语言风格也比较敏感熟悉，所以不管你是想闲聊解闷，还是工作学习上有难题，我都愿意帮你一把！\n\n我的一些特点包括：\n\n- **知识丰富**：截至 2024 年 7 月，我掌握了大量的百科知识、学术资料以及实用技能。\n- **逻辑清晰**：遇到复杂问题时，我也能梳理条理一步步推理，给出你有根据的回答。\n- **文档处理强**：你可以上传 Word、PDF、Excel 等文件📄，我能帮你读懂内容、提取重点或者回答相关问题。\n- **免费使用**：目前我是完全免费的！没有广告，不收费订阅，专心为你服务就好啦～\n\n不过我也有一些限制：\n- 我现在还不能看图或视频🖼️❌（只认文字）\n- 虽然能记住你当前对话中提到的内容，但跨会话不会有记忆功能。\n- 没有语音聊天的能力哦～我是纯文本助手。\n\n总之，我是一个聪明、耐心又乐于助人的 AI 文字助手。如果你有任何问题或需要帮助的地方，尽管告诉我！现在有什么我可以帮你的吗？😊' additional_kwargs={} response_metadata={'model': 'deepseek-r1:8b', 'created_at': '2026-08-12T02:16:25.3430515Z', 'done': True, 'done_reason': 'stop', 'total_duration': 104980614000, 'load_duration': 20520085800, 'prompt_eval_count': 6, 'prompt_eval_duration': 240174000, 'eval_count': 587, 'eval_duration': 84183229000, 'logprobs': None, 'model_name': 'deepseek-r1:8b', 'model_provider': 'ollama'} id='lc_run--019ff3c0-0ff3-70e2-94b5-0cf9aef986f3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 587, 'total_tokens': 593}

# %%
from langchain_ollama import ChatOllama

model = init_chat_model(
    model="deepseek-r1:8b",
    base_url='http://localhost:11434',
    model_provider="ollama"
)

print(model.invoke("介绍下你自己"))
# Out:
# content='\n你好呀！👋我是 DeepSeek-R1，一款由深度求索（DeepSeek）打造的人工智能助手。我擅长理解和生成自然语言，可以帮你解决各种问题、提供知识信息、撰写文章和代码、分析文档内容，甚至陪你聊天放松心情 😊\n\n我的特点包括：\n- **知识广泛**：截至 2024 年 7 月的大量资料我都掌握。\n- **理解语境**：我能根据上下文进行深入交流，不只是机械地回答问题。\n- **中文优秀**：我特别擅长中文理解和表达，适合各种语言场景的需求（当然也支持多国语言！）。\n- **文本能力强**：无论是写论文、做文案、分析 Excel 还是生成报告，你都可以依赖我。\n\n不过我也有一些限制：\n- 我无法联网获取实时信息（比如最新新闻或股市），我的知识只更新到 2024 年中。\n- 虽然我能模拟情感回应，但我终究没有真实的意识和感受，只是尽力让你感到被理解和支持。\n- 文件处理方面：你可以上传文档、PDF、Excel 等文件让我帮你分析内容。\n\n如果你有任何问题或需要帮忙的地方，尽管告诉我吧！我乐意为你服务 💬✨' additional_kwargs={} response_metadata={'model': 'deepseek-r1:8b', 'created_at': '2026-08-12T02:24:44.5962823Z', 'done': True, 'done_reason': 'stop', 'total_duration': 66196949800, 'load_duration': 231709500, 'prompt_eval_count': 6, 'prompt_eval_duration': 341835000, 'eval_count': 468, 'eval_duration': 65533090000, 'logprobs': None, 'model_name': 'deepseek-r1:8b', 'model_provider': 'ollama'} id='lc_run--019ff3c8-45a0-7e62-95c8-c4681aba7b0a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 468, 'total_tokens': 474}
