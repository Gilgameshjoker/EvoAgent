# %%
import os

#调用线上的大模型

## 1. 调用具体厂商的大模型

### 1.1 调用DeepSeek官网的大模型
## 将参数存放在.env文件中

from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv

#读取.env文件中的配置信息
load_dotenv(override=True)
DEEPSEEK_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_URL = os.getenv("DEEPSEEK_BASE_URL")


# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="sk-cf7ade6fd155489b97dd133573ec1e7c",
    api_base="https://api.deepseek.com"
)

# 模型的调用
#response = llm_deepseek.invoke("你好")
#response = llm_deepseek.invoke("你会写python代码吗")
response = llm_deepseek.invoke("你会写悬疑小说吗？")
print(response)
# Out:
# content='当然可以。悬疑小说的核心在于“未知的恐惧”与“逻辑的博弈”，我来构思一个现代都市背景的短篇，注重心理压迫感和细节伏笔。\n\n---\n\n## 完美的不在场证明\n\n深夜十一点，老刑警陈国栋独自坐在刑侦支队档案室里，对着投影屏幕上的照片出神。照片里是一间整洁的公寓，客厅地板上用白线画着人形轮廓。死者叫林芳，独居，死于昨晚八点至十点之间，颈部被利器割断，失血过多。\n\n所有证据都指向她的前男友王磊——他曾在小区门口被公共摄像头拍到，时间正是昨晚九点。他手里提着水果袋，走入监控范围，半小时后匆匆离开，外套袖口有深色污渍。\n\n但王磊有证人，一个无懈可击的证人。\n\n“我当晚和王磊在一起，在他的画室，从晚上七点到十一点。”说话的是许晴，市美术馆的策展人，面容白皙，眼神平静，“他一直在给一幅未完成的油画收尾，我在旁边看书。我们有自拍，还有他调色盘上干涸的颜料。”\n\n陈国栋见过那张自拍。背景确实是画室，墙上挂着半成品的风景画，王磊穿着一件沾着油彩的灰色卫衣，许晴举着手机，两人都看向镜头。时间戳是晚上八点四十七分。\n\n“这张照片有问题。”陈国栋喃喃自语，把画面放大到许晴的眼睛。她的瞳孔里有一个极淡的倒影，像是窗外的什么物体。而在画室的窗户外面，应该正对着老城区的巷子，不可能有那种金属反光。\n\n他调出案发当晚的交通记录。一辆黑色的SUV在七点四十五分驶入老城区，停在距巷口五十米外的阴影处，之后没有驶出记录。车牌号被泥浆糊住，但车顶的天线样式很特殊——像是专业的卫星通信设备。\n\n陈国栋站起身，从保险柜里取出一个密封证物袋，里面是林芳手机里最后一条短信，发给一个未存储的号码：“你终于来找我了。我知道你那天在车里的理由，但这件事不能怪王磊。”\n\n那天，指的是三年前的一起车祸。一个雨夜，一辆黑色SUV冲下江堤，车内女子当场死亡。她叫陈静，是陈国栋的女儿。警方调查后认定为意外，但陈国栋始终觉得，那个雨夜出现在现场的人不止一个。\n\n他拨通了王磊的电话：“许晴的证词，我查过了。她当晚确实在画室，但那部手机被放在定时云台架上，自动拍摄了全过程。她后来剪辑过，从她的角度看起来是正常聊天，其实她一直在看挂钟，每隔十分钟就会瞳孔收缩一次——那是人在计算时间时的微表情。”\n\n电话那头沉默了许久，王磊嘶哑的声音传来：“陈警官，许晴是我的投资人。她
# ...
